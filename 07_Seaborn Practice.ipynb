# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(tips["total_bill"], kde=False)

# %%
sns.jointplot(x="total_bill", y="tip", data=tips)

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="kde") #kind =hex, reg, kde

# %%
sns.pairplot(tips, hue="sex",palette="coolwarm") #palette(colors)

# %%
sns.rugplot(tips["total_bill"],color="red")
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.kdeplot(tips["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#CATEGORICAL PLOTS

# %%
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x="time", y="tip", data =tips)
# Out:
# <Axes: xlabel='time', ylabel='tip'>

# %%
sns.countplot(x="day", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.violinplot(x="day", y="tip", data=tips, hue="sex", split=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x="day", y="tip", data =tips,hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x="day", y="total_bill", data=tips, hue="sex", jitter =True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y="total_bill", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="violin")

# %%
##MATRIX PLOTS

# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig= sns.load_dataset("flights")
fig.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
tc=tips.corr(numeric_only=True) # Add numeric_only

# %%
sns.heatmap(tc, cmap="coolwarm", linewidth=1, linecolor="black")
# Out:
# <Axes: >

# %%
fig
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
fp =fig.pivot_table(index="month", columns="year", values="passengers")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13984\2198428154.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   fp =fig.pivot_table(index="month", columns="year", values="passengers")

# %%
sns.heatmap(fp, cmap="coolwarm")
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(fp,cmap="coolwarm", standard_scale=1)

# %% [markdown]
# ### GRID PLOTS

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(iris)

# %%
sns.PairGrid(iris)

# %%
g= sns.PairGrid(iris)
g.map_diag(sns.displot)
g.map_lower(sns.kdeplot)
g.map_upper(plt.scatter)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
g = sns.FacetGrid(data =tips, col="time", row="smoker")
g.map(plt.scatter, "total_bill","tip")

# %%
g.map(sns.displot, "total_bill")
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### REGRESSION PLOTS

# %%
import seaborn as sns
# %matplotlib inline
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x="total_bill", y="tip", data=tips, hue="sex", markers =["o","v"], scatter_kws={"s":100})

# %%
sns.lmplot(x="total_bill", y="tip", data=tips, col="sex", row="smoker", aspect=0.6)
