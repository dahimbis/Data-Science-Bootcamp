# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x = np.linspace(0,11,5)

# %%
y = x**2

# %%
plt.plot(x,y,"y")
plt.xlabel("Numbers")
plt.ylabel("Num")
plt.title("Numpy numbers using Linspace")
# Out:
# Text(0.5, 1.0, 'Numpy numbers using Linspace')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,"r")
plt.subplot(1,2,2)
plt.plot(y,x,"g")

# %%
fig = plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.4,0.2,0.3])
axes1.plot(x,y,"y")
axes2.plot(y,x,"r")
                   
axes1.set_title("LARGE PLOT")
axes2.set_title("SMALLER PLOT")
axes.set_xlabel("Number")
axes.set_ylabel("Nums")
#Fourth is heigh
#3rd is the width
#2nd is the bottom position of lower
#1st is the left position of lower left corner
# Out:
# Text(24.0, 0.5, 'Nums')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
for current_ax in axes:
    current_ax.plot(x,y)

# %%
fig, axes = plt.subplots(nrows = 1, ncols =2)

axes[1].plot(x,y,"r")
axes[1].set_title("Small")
axes[0].plot(y,x,"y")
axes[0].set_title("Big")
# Out:
# Text(0.5, 1.0, 'Big')

# %%
fig

# %%
fig.savefig("Dan.png") #saving a figure

# %%
fig, axes= plt.subplots(figsize=(4,4))
axes.plot(x, x**2, label ="Figure One")
axes.plot(x,x**3, label ="Figure Two")
axes.legend(loc=0)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


x = np.linspace(0,11,5)
y = x**2

# %%
fig = plt.figure(figsize=(5,5))
axes = fig.add_axes([0,0,1,1])

axes.plot(x,y, color="red", marker="o", linewidth=1, linestyle="-")
axes.set_xlim([0,2])
axes.set_ylim([10,2]) 
#Setting Limits
# Out:
# (10.0, 2.0)
