# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %%
np.random.seed(101) #Seeds makes random data constant

# %%
df = pd.DataFrame(randn(5,4), ["A","B","C","D","E"],["W","X","Y","Z"])

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
#SELECTING COLUMNS

# %%
df["W"]
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
df[["W","Z"]]
# Out:
#           W         Z
# A  2.706850  0.503826
# B  0.651118  0.605965
# C -2.018168 -0.589001
# D  0.188695  0.955057
# E  0.190794  0.683509

# %%
df['M'] = df["W"]+ df["X"]

# %%
df
# Out:
#           W         X         Y         Z         M
# A  2.706850  0.628133  0.907969  0.503826  3.334983
# B  0.651118 -0.319318 -0.848077  0.605965  0.331800
# C -2.018168  0.740122  0.528813 -0.589001 -1.278046
# D  0.188695 -0.758872 -0.933237  0.955057 -0.570177
# E  0.190794  1.978757  2.605967  0.683509  2.169552

# %%
df.drop("M", axis =1) #for columns specify the axis, 1 for colum, 0 for 1
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
#selecting rows

# %%
df.loc["A"] #using the item
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# M    3.334983
# Name: A, dtype: float64

# %%
df.iloc[2] #iloc for selecting using the numerical values
# Out:
# W   -2.018168
# X    0.740122
# Y    0.528813
# Z   -0.589001
# M   -1.278046
# Name: C, dtype: float64

# %%
df.iloc[4]
# Out:
# W    0.190794
# X    1.978757
# Y    2.605967
# Z    0.683509
# M    2.169552
# Name: E, dtype: float64

# %%
df.drop("A", axis=0)
# Out:
#           W         X         Y         Z         M
# B  0.651118 -0.319318 -0.848077  0.605965  0.331800
# C -2.018168  0.740122  0.528813 -0.589001 -1.278046
# D  0.188695 -0.758872 -0.933237  0.955057 -0.570177
# E  0.190794  1.978757  2.605967  0.683509  2.169552

# %%
df.loc[["C","D"],["W","M"]] #SELECTING C,D and W, M
# Out:
#           W         M
# C -2.018168 -1.278046
# D  0.188695 -0.570177

# %%
#CONDITIONAL

# %%
df>0
# Out:
#        W      X      Y      Z      M
# A   True   True   True   True   True
# B   True  False  False   True   True
# C  False   True   True  False  False
# D   True  False  False   True  False
# E   True   True   True   True   True

# %%
df[df>0]
# Out:
#           W         X         Y         Z         M
# A  2.706850  0.628133  0.907969  0.503826  3.334983
# B  0.651118       NaN       NaN  0.605965  0.331800
# C       NaN  0.740122  0.528813       NaN       NaN
# D  0.188695       NaN       NaN  0.955057       NaN
# E  0.190794  1.978757  2.605967  0.683509  2.169552

# %%
df[df["W"]>0]
# Out:
#           W         X         Y         Z         M
# A  2.706850  0.628133  0.907969  0.503826  3.334983
# B  0.651118 -0.319318 -0.848077  0.605965  0.331800
# D  0.188695 -0.758872 -0.933237  0.955057 -0.570177
# E  0.190794  1.978757  2.605967  0.683509  2.169552

# %%
df[df["M"]<0][["W","X"]] #Get where M is less than 0, then grap values for W AND X
# Out:
#           W         X
# C -2.018168  0.740122
# D  0.188695 -0.758872

# %%
df["new"] = "CA NY LOS LAZ JA".split()

# %%
df
# Out:
#           W         X         Y         Z         M  new
# A  2.706850  0.628133  0.907969  0.503826  3.334983   CA
# B  0.651118 -0.319318 -0.848077  0.605965  0.331800   NY
# C -2.018168  0.740122  0.528813 -0.589001 -1.278046  LOS
# D  0.188695 -0.758872 -0.933237  0.955057 -0.570177  LAZ
# E  0.190794  1.978757  2.605967  0.683509  2.169552   JA

# %%
df.set_index("new") #Setting New Index
# Out:
#             W         X         Y         Z         M
# new
# CA   2.706850  0.628133  0.907969  0.503826  3.334983
# NY   0.651118 -0.319318 -0.848077  0.605965  0.331800
# LOS -2.018168  0.740122  0.528813 -0.589001 -1.278046
# LAZ  0.188695 -0.758872 -0.933237  0.955057 -0.570177
# JA   0.190794  1.978757  2.605967  0.683509  2.169552

# %%
df.reset_index() #Resettng Index to Default
# Out:
#   index         W         X         Y         Z         M  new
# 0     A  2.706850  0.628133  0.907969  0.503826  3.334983   CA
# 1     B  0.651118 -0.319318 -0.848077  0.605965  0.331800   NY
# 2     C -2.018168  0.740122  0.528813 -0.589001 -1.278046  LOS
# 3     D  0.188695 -0.758872 -0.933237  0.955057 -0.570177  LAZ
# 4     E  0.190794  1.978757  2.605967  0.683509  2.169552   JA

# %%
# Index Levels
outside = ['D1','D1','D1','D2','D2','D2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
outside
# Out:
# ['D1', 'D1', 'D1', 'D2', 'D2', 'D2']

# %%
inside
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
hier_index
# Out:
# MultiIndex([('D1', 1),
#             ('D1', 2),
#             ('D1', 3),
#             ('D2', 1),
#             ('D2', 2),
#             ('D2', 3)],
#            )

# %%
hier_index
# Out:
# MultiIndex([('D1', 1),
#             ('D1', 2),
#             ('D1', 3),
#             ('D2', 1),
#             ('D2', 2),
#             ('D2', 3)],
#            )

# %%
df = pd.DataFrame(randn(5,4), ["A", "B","C","D","E"])

# %%
df
# Out:
#           0         1         2         3
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %%
df = pd.DataFrame(randn(6,4), hier_index,["A","B","C","D"])

# %%
df
# Out:
#                          A         B         C         D
# Categories Names
# D1         1      0.041460 -0.411055 -0.771329  0.110477
#            2     -0.804652  0.253548  0.649148  0.358941
#            3     -1.080471  0.902398  0.161781  0.833029
# D2         1      0.975720 -0.388239  0.783316 -0.708954
#            2      0.586847 -1.621348  0.677535  0.026105
#            3     -1.678284  0.333973 -0.532471  2.117727

# %%
df.index.names= ["Categories", "Num"]

# %%
df
# Out:
#                        A         B         C         D
# Categories Num
# D1         1    0.041460 -0.411055 -0.771329  0.110477
#            2   -0.804652  0.253548  0.649148  0.358941
#            3   -1.080471  0.902398  0.161781  0.833029
# D2         1    0.975720 -0.388239  0.783316 -0.708954
#            2    0.586847 -1.621348  0.677535  0.026105
#            3   -1.678284  0.333973 -0.532471  2.117727

# %%
df.loc["D1"]
# Out:
#             A         B         C         D
# Num
# 1    0.041460 -0.411055 -0.771329  0.110477
# 2   -0.804652  0.253548  0.649148  0.358941
# 3   -1.080471  0.902398  0.161781  0.833029

# %%
df
# Out:
#                        A         B         C         D
# Categories Num
# D1         1    0.041460 -0.411055 -0.771329  0.110477
#            2   -0.804652  0.253548  0.649148  0.358941
#            3   -1.080471  0.902398  0.161781  0.833029
# D2         1    0.975720 -0.388239  0.783316 -0.708954
#            2    0.586847 -1.621348  0.677535  0.026105
#            3   -1.678284  0.333973 -0.532471  2.117727

# %%
df.loc["D2"].loc[2].loc["B"] #selecting -1.621
# Out:
# -1.621347825454474

# %%
df.xs(1, level="Num")
# Out:
#                   A         B         C         D
# Categories
# D1          0.04146 -0.411055 -0.771329  0.110477
# D2          0.97572 -0.388239  0.783316 -0.708954

# %%
#missing values

# %%
d = {"A":[1, 2,np.nan],"B":[3, np.nan, 4], "C": [3,4,5]}

# %%
d
# Out:
# {'A': [1, 2, nan], 'B': [3, nan, 4], 'C': [3, 4, 5]}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#      A    B  C
# 0  1.0  3.0  3
# 1  2.0  NaN  4
# 2  NaN  4.0  5

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  3.0  3

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  3
# 1  4
# 2  5

# %%
df.fillna(value =np.mean(5))
# Out:
#      A    B  C
# 0  1.0  3.0  3
# 1  2.0  5.0  4
# 2  5.0  4.0  5

# %%
#GROUPING BY

# %%
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}

# %%
data
# Out:
# {'Company': ['GOOG', 'GOOG', 'MSFT', 'MSFT', 'FB', 'FB'],
#  'Person': ['Sam', 'Charlie', 'Amy', 'Vanessa', 'Carl', 'Sarah'],
#  'Sales': [200, 120, 340, 124, 243, 350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
by=df.groupby("Company")

# %%
by.sum()
# Out:
#              Person  Sales
# Company
# FB        CarlSarah    593
# GOOG     SamCharlie    320
# MSFT     AmyVanessa    464

# %%
by.min()
# Out:
#           Person  Sales
# Company
# FB          Carl    243
# GOOG     Charlie    120
# MSFT         Amy    124

# %%
by.max()
# Out:
#           Person  Sales
# Company
# FB         Sarah    350
# GOOG         Sam    200
# MSFT     Vanessa    340

# %%
df.groupby("Company").describe().transpose()
# Out:
# Company              FB        GOOG        MSFT
# Sales count    2.000000    2.000000    2.000000
#       mean   296.500000  160.000000  232.000000
#       std     75.660426   56.568542  152.735065
#       min    243.000000  120.000000  124.000000
#       25%    269.750000  140.000000  178.000000
#       50%    296.500000  160.000000  232.000000
#       75%    323.250000  180.000000  286.000000
#       max    350.000000  200.000000  340.000000

# %%
# Concant, #Join # Merge

# %%
#Inner returns matching records, outer returns both matching records and non matching ones

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7])

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
pd.concat([df1, df2, df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1, df2, df3], axis=1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(left, right)
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
pd.merge(left, right, how="outer")
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
left = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
right
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(left, right, how="outer")
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K0   K1   A1   B1  NaN  NaN
# 2   K1   K0   A2   B2   C1   D1
# 3   K1   K0   A2   B2   C2   D2
# 4   K2   K0  NaN  NaN   C3   D3
# 5   K2   K1   A3   B3  NaN  NaN

# %%
pd.merge(left, right, how="right")
# Out:
#   key1 key2    A    B   C   D
# 0   K0   K0   A0   B0  C0  D0
# 1   K1   K0   A2   B2  C1  D1
# 2   K1   K0   A2   B2  C2  D2
# 3   K2   K0  NaN  NaN  C3  D3

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
left.join(right)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
left.join(right, how="outer")
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
#OPERATIONS IN PANDAS

# %%
df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df["col2"].unique()
# Out:
# array([444, 555, 666], dtype=int64)

# %%
df["col2"].nunique()
# Out:
# 3

# %%
df["col2"].value_counts() #count number of values
# Out:
# col2
# 444    2
# 555    1
# 666    1
# Name: count, dtype: int64

# %%
def times2(x):
    return x*2

# %%
df['col2'].apply(times2) #apply is used for functions
# Out:
# 0     888
# 1    1110
# 2    1332
# 3     888
# Name: col2, dtype: int64

# %%
df['col2'].apply(lambda x: x*2) # this is same as calling the function - use lambda instead of creating a function
# Out:
# 0     888
# 1    1110
# 2    1332
# 3     888
# Name: col2, dtype: int64

# %%
df.columns
# Out:
# Index(['col1', 'col2', 'col3'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.isnull()
# Out:
#     col1   col2   col3
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False

# %%
df.sort_values("col2")
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi

# %%
data = {'A':['foo','foo','foo','bar','bar','bar'],
     'B':['one','one','two','two','one','one'],
       'C':['x','y','x','y','x','y'],
       'D':[1,3,2,5,4,1]}

df = pd.DataFrame(data)

# %%
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
df.pivot_table(values="D", index=["A","B"])
# Out:
#            D
# A   B
# bar one  2.5
#     two  5.0
# foo one  2.0
#     two  2.0

# %%
df.pivot_table(values="D", index=["A","B"], columns="C")
# Out:
# C          x    y
# A   B
# bar one  4.0  1.0
#     two  NaN  5.0
# foo one  1.0  3.0
#     two  2.0  NaN

# %%
pwd #print current directory
# Out:
# 'C:\\Users\\User\\Desktop\\Data Science\\Pandas'

# %%
df = pd.read_csv("customers-100.csv")

# %%
df.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
df.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
df.isnull()
# Out:
#     Index  Customer Id  First Name  Last Name  Company   City  Country  \
# 0   False        False       False      False    False  False    False
# 1   False        False       False      False    False  False    False
# 2   False        False       False      False    False  False    False
# 3   False        False       False      False    False  False    False
# 4   False        False       False      False    False  False    False
# ..    ...          ...         ...        ...      ...    ...      ...
# 95  False        False       False      False    False  False    False
# 96  False        False       False      False    False  False    False
# 97  False        False       False      False    False  False    False
# 98  False        False       False      False    False  False    False
# 99  False        False       False      False    False  False    False
#
#     Phone 1  Phone 2  Email  Subscription Date  Website
# 0     False    False  False              False    False
# ...

# %%
df = pd.read_excel("Excel_Sample.xlsx", sheet_name="Sheet1") #Reading Excel File

# %%
df
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df.to_excel("New Sheet.xlsx", sheet_name="Sheet1")

# %%
data = pd.read_html("https://www.fdic.gov/bank-failures/failed-bank-list")

# %%
data
# Out:
# [                               Bank Name               City         State  \
#  0                   Pulaski Savings Bank            Chicago      Illinois
#  1     The First National Bank of Lindsay            Lindsay      Oklahoma
#  2  Republic First Bank dba Republic Bank       Philadelphia  Pennsylvania
#  3                          Citizens Bank           Sac City          Iowa
#  4               Heartland Tri-State Bank            Elkhart        Kansas
#  5                    First Republic Bank      San Francisco    California
#  6                         Signature Bank           New York      New York
#  7                    Silicon Valley Bank        Santa Clara    California
#  8                      Almena State Bank             Almena        Kansas
#  9             First City Bank of Florida  Fort Walton Beach       Florida
#
#      Cert                Acquiring Institution      Closing Date  \
#  0  28611                      Millennium Bank  January 17, 2025
# ...

# %%
data[0].head()
# Out:
#                                Bank Name          City         State   Cert  \
# 0                   Pulaski Savings Bank       Chicago      Illinois  28611
# 1     The First National Bank of Lindsay       Lindsay      Oklahoma   4134
# 2  Republic First Bank dba Republic Bank  Philadelphia  Pennsylvania  27332
# 3                          Citizens Bank      Sac City          Iowa   8758
# 4               Heartland Tri-State Bank       Elkhart        Kansas  25851
#
#                 Acquiring Institution      Closing Date  Fund  Sort ascending
# 0                     Millennium Bank  January 17, 2025                 10548
# 1  First Bank & Trust Co., Duncan, OK  October 18, 2024                 10547
# 2   Fulton Bank, National Association    April 26, 2024                 10546
# 3           Iowa Trust & Savings Bank  November 3, 2023                 10545
# 4              Dream First Bank, N.A.     July 28, 2023                 10544

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
df.to_sql('data', engine)
# Out:
# 4

# %%
sql_df = pd.read_sql('data',con=engine)

# %%
sql_df
# Out:
#    index  Unnamed: 0   a   b   c   d
# 0      0           0   0   1   2   3
# 1      1           1   4   5   6   7
# 2      2           2   8   9  10  11
# 3      3           3  12  13  14  15

# %% [markdown]
# #GOOD BYE!!!
